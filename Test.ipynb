# %%
import pandas as pd
import altair as alt

# %%
vol_df = pd.read_csv('data/Volcanoes_cleaned.csv')

# %%
vol_df_sum = vol_df.groupby('Country').agg('count')

# %%
vol_df_sum = vol_df_sum.reset_index()
vol_df_sum.head(5)
# Out:
#    index     Country  Year  Mo  Dy  Tsu  Eq  Name  Location  latitude  ...  \
# 0      0  Cape Verde     2   2   2    0   0     2         2         2  ...
# 1      1       Chile     4   4   4    0   0     4         4         4  ...
# 2      2    Colombia     4   4   4    0   1     4         4         4  ...
# 3      3     Comoros     2   2   2    0   0     2         2         2  ...
# 4      4  Congo, DRC     3   3   3    0   1     3         3         3  ...
#
#    Total Death Description  Total Missing  Total Missing Description  \
# 0                        0              0                          0
# 1                        1              0                          0
# 2                        3              0                          1
# 3                        1              0                          0
# 4                        3              0                          0
#
#    Total Injuries  Total Injuries Description  Total Damage ($Mil)  \
# ...

# %%
alt.Chart(vol_df_sum).mark_bar().encode(
        x=alt.X("Country:N").axis(labelAngle=0),
        y="Name:Q",
        shape='Origin'
    )
# Out:
# C:\Users\Matt\anaconda3\Lib\site-packages\altair\utils\core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\Lib\site-packages\altair\vegalite\v5\api.py in ?(self, include, exclude)
#    2154         # see https://github.com/ipython/ipython/issues/11038
#    2155         try:
#    2156             dct = self.to_dict()
#    2157         except Exception:
# -> 2158             utils.display_traceback(in_ipython=True)
#    2159             return {}
#    2160         else:
#    2161             return renderers.get()(dct)
#
# ~\anaconda3\Lib\site-packages\altair\vegalite\v5\api.py in ?(self, *args, **kwargs)
# ...
